# %%
import pandas as pd
df=pd.read_csv('C://Users//Prasad//Downloads//Olympic_dataset//dataset_olympics.csv')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.shape
## df has 70000 rows and 15 columns.
# Out:
# (70000, 15)

# %%
df=df.drop(columns=['Height','Weight'])
## droping height and weight columns from dataframe.

# %%
df
# Out:
#           ID                            Name Sex   Age            Team  NOC  \
# 0          1                       A Dijiang   M  24.0           China  CHN
# 1          2                        A Lamusi   M  23.0           China  CHN
# 2          3             Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3          4            Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4          5        Christine Jacoba Aaftink   F  21.0     Netherlands  NED
# ...      ...                             ...  ..   ...             ...  ...
# 69995  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69996  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0       Australia  AUS
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0       Australia  AUS
# 69999  35658                    Marek Fiurek   M  23.0  Czech Republic  CZE
#
# ...

# %%
df.shape
##after deletion of two columns height and weight, the column is changed from 15 to 13.
# Out:
# (70000, 13)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69995    False
# 69996    False
# 69997    False
# 69998    False
# 69999    False
# Length: 70000, dtype: bool

# %%
duplicated_true=df.duplicated().sum()

# %%
duplicated_true
## here I can see there are 383 duplicated rows are there in the dataframe. Because every true value has 1 and false has zero.
# Out:
# 383

# %%
df[df.duplicated()]
## returns 383 rows which are duplicate rows.
# Out:
#           ID                    Name Sex   Age           Team  NOC  \
# 1252     704      Dsir Antoine Acket   M  27.0        Belgium  BEL
# 4282    2449  William Truman Aldrich   M  48.0  United States  USA
# 4283    2449  William Truman Aldrich   M  48.0  United States  USA
# 4862    2777  Hermann Reinhard Alker   M  43.0        Germany  GER
# 4864    2777  Hermann Reinhard Alker   M  43.0        Germany  GER
# ...      ...                     ...  ..   ...            ...  ...
# 67774  34642   Clara Beatrice Fenton   F  45.0  United States  USA
# 69050  35215     Pedro Figari Solari   M  71.0        Uruguay  URU
# 69051  35215     Pedro Figari Solari   M  71.0        Uruguay  URU
# 69052  35215     Pedro Figari Solari   M  71.0        Uruguay  URU
# 69053  35215     Pedro Figari Solari   M  71.0        Uruguay  URU
#
#              Games  Year  Season         City             Sport  \
# 1252   1932 Summer  1932  Summer  Los Angeles  Art Competitions
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df=df.drop_duplicates()
## deleted 383 rows from data frame. returns 69617 rows.

# %%
df.shape
# Out:
# (69617, 13)

# %%
pd.isnull(df).sum()
## here I can see there are 2732 null values in 'Age' column and 60310 null values in 'Medal' column.
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2671
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     59931
# dtype: int64

# %%
df['Medal'].fillna('Medal-less',inplace=True)
## filling NAN values in 'Medal' column in data frame with 'Medal-less'.
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\957364427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Medal'].fillna('Medal-less',inplace=True)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age            Team  NOC        Games  \
# 0   1                 A Dijiang   M  24.0           China  CHN  1992 Summer
# 1   2                  A Lamusi   M  23.0           China  CHN  2012 Summer
# 2   3       Gunnar Nielsen Aaby   M  24.0         Denmark  DEN  1920 Summer
# 3   4      Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN  1900 Summer
# 4   5  Christine Jacoba Aaftink   F  21.0     Netherlands  NED  1988 Winter
#
#    Year  Season       City          Sport                             Event  \
# 0  1992  Summer  Barcelona     Basketball       Basketball Men's Basketball
# 1  2012  Summer     London           Judo      Judo Men's Extra-Lightweight
# 2  1920  Summer  Antwerpen       Football           Football Men's Football
# 3  1900  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  1988  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres
#
#         Medal
# 0  Medal-less
# 1  Medal-less
# ...

# %%
Age_median=df['Age'].median()
Age_median
# Out:
# 24.0

# %%
df['Age'].fillna(Age_median,inplace=True)
##filling NAN values in 'Age' column in data frame with median of Age.
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\2826513955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].fillna(Age_median,inplace=True)

# %%
pd.isnull(df).sum()
## I confirm here that there are no null values present in the data frame.
# Out:
# ID        0
# Name      0
# Sex       0
# Age       0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
df.shape
# Out:
# (69617, 13)

# %%
df.to_csv('C://Users//Prasad//Downloads//Olympic_dataset//olympics_history__jupiter_cleaned.csv', index=False)

# %% [markdown]
# Visualize
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
#Top 5 most successful countries in olympics. Success is defined by no of medals won.
df.head()
# Out:
#    ID                      Name Sex   Age            Team  NOC        Games  \
# 0   1                 A Dijiang   M  24.0           China  CHN  1992 Summer
# 1   2                  A Lamusi   M  23.0           China  CHN  2012 Summer
# 2   3       Gunnar Nielsen Aaby   M  24.0         Denmark  DEN  1920 Summer
# 3   4      Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN  1900 Summer
# 4   5  Christine Jacoba Aaftink   F  21.0     Netherlands  NED  1988 Winter
#
#    Year  Season       City          Sport                             Event  \
# 0  1992  Summer  Barcelona     Basketball       Basketball Men's Basketball
# 1  2012  Summer     London           Judo      Judo Men's Extra-Lightweight
# 2  1920  Summer  Antwerpen       Football           Football Men's Football
# 3  1900  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  1988  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres
#
#         Medal
# 0  Medal-less
# 1  Medal-less
# ...

# %%
df.shape
# Out:
# (69617, 13)

# %%
Medals_won_df=df.loc[df['Medal'].str.contains('Gold|Silver|Bronze')]
Medals_won_df
# Out:
#           ID                                  Name Sex   Age            Team  \
# 3          4                  Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# 37        15                  Arvo Ossian Aaltonen   M  30.0         Finland
# 38        15                  Arvo Ossian Aaltonen   M  30.0         Finland
# 40        16              Juhamatti Tapio Aaltonen   M  28.0         Finland
# 41        17               Paavo Johannes Aaltonen   M  28.0         Finland
# ...      ...                                   ...  ..   ...             ...
# 69957  35636       Joseph Francis "Joe" Fitzgerald   M  27.0   United States
# 69974  35644  Benita P. Fitzgerald-Brown (-Mosley)   F  23.0   United States
# 69977  35647          James Paul "Jim" Fitzpatrick   M  27.0   United States
# 69983  35651         Theresa Matauaina Fitzpatrick   F  21.0     New Zealand
# 69988  35653                 Casey J. FitzRandolph   M  27.0   United States
#
# ...

# %%
#Top 5 most Medals won Countries, order the result by number of medals in descending order
import pandas as pd
#Grouping by country
Medals_won_by_country=Medals_won_df.groupby(['NOC'])['Medal'].count()

#sorting in descending order
Medals_won_by_country_desc=Medals_won_by_country.sort_values(ascending = False)

#Bring first 5 rows
Top_5_most_Medals_won_Countries=Medals_won_by_country_desc.head(5)
Top_5_most_Medals_won_Countries

#creating data frame for top 5 most medals won countries
Top_5_most_Medals_won_Countries_df= pd.DataFrame(Top_5_most_Medals_won_Countries)
Top_5_most_Medals_won_Countries_df.reset_index(inplace=True)
Top_5_most_Medals_won_Countries_df
# Out:
#    NOC  Medal
# 0  USA   1561
# 1  FRA    657
# 2  ITA    604
# 3  GBR    603
# 4  URS    515

# %%
#calculating percentages of Medals won
Top_5_most_Medals_won_Countries_df['percentage']=round(Top_5_most_Medals_won_Countries_df['Medal']/Top_5_most_Medals_won_Countries_df['Medal'].sum(),3)*100
Top_5_most_Medals_won_Countries_df
# Out:
#    NOC  Medal  percentage
# 0  USA   1561        39.6
# 1  FRA    657        16.7
# 2  ITA    604        15.3
# 3  GBR    603        15.3
# 4  URS    515        13.1

# %%
# Doughnut Chart
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
 
top5_countries_won_medals=list(Top_5_most_Medals_won_Countries_df['NOC'])
top5_countries_won_medals_count=list(Top_5_most_Medals_won_Countries_df['Medal'])

# colors
colors = ['#FF0000', '#0000FF', '#FFFF00',
          '#ADFF2F', '#FFA500']

# explosion
explode = (0.05, 0.05, 0.05, 0.05, 0.05)
 
# Pie Chart
plt.pie(top5_countries_won_medals_count, colors=colors, labels=top5_countries_won_medals,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)
 
# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
 
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)
 
# Adding Title of chart
plt.title('Top 5 most successful countries in olympics',color = 'white')
 
# Displaying Chart
plt.show()

# %%
#No of Gold, Silver and Bronze medals won by top 5 most successfull countries
Medals_won_df=Medals_won_df.set_index('NOC')
Medals_won_df
Medals_won_df.loc[Medals_won_df['Medal']=='Gold','Gold']=1
Medals_won_df.loc[Medals_won_df['Medal']=='Silver','Silver']=1
Medals_won_df.loc[Medals_won_df['Medal']=='Bronze','Bronze']=1
Medals_won_df
# Out:
#         ID                                  Name Sex   Age            Team  \
# NOC
# DEN      4                  Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# FIN     15                  Arvo Ossian Aaltonen   M  30.0         Finland
# FIN     15                  Arvo Ossian Aaltonen   M  30.0         Finland
# FIN     16              Juhamatti Tapio Aaltonen   M  28.0         Finland
# FIN     17               Paavo Johannes Aaltonen   M  28.0         Finland
# ..     ...                                   ...  ..   ...             ...
# USA  35636       Joseph Francis "Joe" Fitzgerald   M  27.0   United States
# USA  35644  Benita P. Fitzgerald-Brown (-Mosley)   F  23.0   United States
# USA  35647          James Paul "Jim" Fitzpatrick   M  27.0   United States
# NZL  35651         Theresa Matauaina Fitzpatrick   F  21.0     New Zealand
# USA  35653                 Casey J. FitzRandolph   M  27.0   United States
#
# ...

# %%
#No of Gold, Silver and Bronze medals won by top 5 most successfull countries
medals=Medals_won_df.groupby(['NOC'])['Gold','Silver','Bronze'].count()
medals['total']=medals.sum(axis = 1)
medals
medals_NOC=medals.sort_values(by=['total'],ascending=False)
top_5_countries=medals_NOC.head(5)
top_5_countries_won_medals=top_5_countries[['Gold','Silver','Bronze']]
top_5_countries_won_medals
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\1631393111.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   medals=Medals_won_df.groupby(['NOC'])['Gold','Silver','Bronze'].count()
#      Gold  Silver  Bronze
# NOC
# USA   747     448     366
# FRA   184     216     257
# ITA   217     193     194
# GBR   210     207     186
# URS   216     150     149

# %%
#No of Gold, Silver and Bronze medals won by top 5 most successfull countries
# bar chart
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
# setting style for graphs
#style.use('Solarize_Light2')
plt.rcParams['figure.figsize'] = (30,16)

plots=top_5_countries_won_medals.plot(kind = 'bar')
plt.title('No of Gold, Silver and Bronze medals won by top 5 most successfull countries',color = 'white',size=30)
plt.xlabel('Country',size=30,color = 'white')
plt.ylabel('No of medals',size=30,color = 'white')
plt.xticks(color = 'white',size=22)
plt.yticks(color = 'white',size=22)
plt.legend(loc='upper right', title='The Legend',prop={'size': 22})
plt.savefig('Line_Chart.png')
for bar in plots.patches:
    plots.annotate(format(int(bar.get_height()), ','),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=22, xytext=(0, 9),
                   textcoords='offset points')
    

plt.show()

# %%
#no of nations participated in olympics
no_of_nations_participated_in_olympics=df['NOC'].nunique()
no_of_nations_participated_in_olympics
# Out:
# 226

# %%
#no of olympic games held
no_of_olympic_games_held=df['Games'].nunique()
no_of_olympic_games_held
# Out:
# 51

# %%
#Mention the total no of nations who participated in each olympics game?
import pandas as pd
no_of_nations_participated_in_olympic_game=df.groupby('Games')['NOC'].nunique()
no_of_nations_participated_in_olympic_game_desc=no_of_nations_participated_in_olympic_game.sort_values(ascending=False)
no_of_nations_participated_in_olympic_game_desc
# Out:
# Games
# 2016 Summer    180
# 2012 Summer    180
# 1996 Summer    178
# 2008 Summer    177
# 2004 Summer    177
# 2000 Summer    173
# 1988 Summer    152
# 1992 Summer    151
# 1984 Summer    134
# 1972 Summer    109
# 1968 Summer     98
# 1976 Summer     84
# 1964 Summer     83
# 1960 Summer     80
# 1980 Summer     75
# 1956 Summer     66
# 1952 Summer     62
# 2014 Winter     62
# 2002 Winter     62
# 2006 Winter     61
# 1998 Winter     57
# 1992 Winter     54
# 2010 Winter     53
# 1948 Summer     52
# 1994 Winter     49
# 1936 Summer     47
# 1988 Winter     46
# 1928 Summer     43
# 1924 Summer     39
# 1984 Winter     39
# 1932 Summer     39
# 1968 Winter     37
# 1964 Winter     33
# 1976 Winter     31
# 1972 Winter     31
# 1980 Winter     29
# 1960 Winter     28
# 1952 Winter     27
# 1920 Summer     26
# 1956 Winter     26
# 1948 Winter     26
# 1936 Winter     24
# 1912 Summer     24
# 1928 Winter     23
# 1900 Summer     20
# 1906 Summer     19
# 1908 Summer     18
# ...

# %%
##Mention the total no of nations who participated in each olympics game?
# bar chart
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
import seaborn as sns
plt.figure(figsize = (14,34))
no_of_nations_participated_in_olympic_game_desc.plot(kind = 'barh',figsize=(14, 14))
plt.title('\n No of nations participated in each olympics game \n',size=22)
plt.ylabel('\n olympic game \n',size=22)
plt.xlabel('\n no of nations\n',size=22)
plt.xticks(color='white',size=22)
plt.yticks(color='white',size=14)

for index, value in enumerate(no_of_nations_participated_in_olympic_game_desc): 
    
    label = int(value)# format int with commas
    plt.annotate(label, xy=(value , index ), color='White',size=14)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#No of Medals won by each Country in olympics
Medal_count_by_country=Medals_won_df.groupby(['NOC'])['Medal'].count()

Medal_count_by_country_desc=Medal_count_by_country.sort_values( ascending = False)
Medal_count_by_country_desc
# Out:
# NOC
# USA    1561
# FRA     657
# ITA     604
# GBR     603
# URS     515
#        ...
# NEP       1
# ISR       1
# MDA       1
# JOR       1
# AHO       1
# Name: Medal, Length: 119, dtype: int64

# %%
#No of Medals won by each Country in olympics
# bar chart
# Do not change the style back to ggplot 
# delete the style.use('ggplot') line of code
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
import seaborn as sns

Medal_count_by_country_desc.plot(kind = 'barh',figsize=(14, 43))
plt.title('\n No of Medals won by each nation \n',size=22)
plt.ylabel('\n Country \n',size=22)
plt.xlabel('\n Medals won\n',size=22)
plt.xticks(color='white',size=22)
plt.yticks(color='white',size=14)



for index, value in enumerate(Medal_count_by_country_desc): 
    
    label = int(value)# format int with commas
    # place text at the end of bar (subtracting 47000 from x, and 0.1 from y to make it fit within the bar)
    plt.annotate(label, xy=(value , index ), color='White',size=14)



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sport played in no of olympic games
sport_played_in_no_of_olympic_games=df.groupby(['Sport'])['Games'].nunique().sort_values(ascending=False)
sport_played_in_no_of_olympic_games
# Out:
# Sport
# Fencing                29
# Athletics              29
# Swimming               29
# Cycling                29
# Gymnastics             29
#                        ..
# Motorboating            1
# Cricket                 1
# Military Ski Patrol     1
# Jeu De Paume            1
# Croquet                 1
# Name: Games, Length: 65, dtype: int64

# %%
#sport played in no of olympic games
# bar chart
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
import seaborn as sns
plt.figure(figsize = (14,34))
sport_played_in_no_of_olympic_games.plot(kind = 'barh',figsize=(14, 24))
plt.title('\n sport played in no of olympic games \n',size=22)
plt.ylabel('\n sport\n',size=22)
plt.xlabel('\n No of olympic games  \n',size=22)
plt.xticks(color='white',size=22)
plt.yticks(color='white',size=14)

for index, value in enumerate(sport_played_in_no_of_olympic_games): 
    
    label = int(value)# format int with commas
    plt.annotate(label, xy=(value , index ), color='White',size=14)

plt.show
# Out:
# C:\Users\Prasad\anaconda3\lib\site-packages\IPython\core\displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#No of Medals won by India in sports in olympics
Medals_won_df
india_df=Medals_won_df.loc[['IND']]
ind=india_df.groupby(['Sport'])['Gold','Silver','Bronze'].count()
ind_medals=ind.transpose()
ind_medals
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\2706563602.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ind=india_df.groupby(['Sport'])['Gold','Silver','Bronze'].count()
# Sport   Hockey  Shooting  Wrestling
# Gold        27         1          0
# Silver       2         0          0
# Bronze       3         0          1

# %%
#No of Medals won by India in sports in olympics
# bar chart
# Do not change the style back to ggplot 
# delete the style.use('ggplot') line of code
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
import seaborn as sns

plots=ind_medals.plot(kind = 'bar',figsize=(9,4))
plt.title('\n No of Medals won by India in sports in olympics \n',size=22)
plt.ylabel('\n No of Medals won \n',size=22)
plt.xlabel('\n Medal Type\n',size=22)
plt.xticks(color='white',size=22)
plt.yticks(color='white',size=14)

for bar in plots.patches:
    plots.annotate(format(int(bar.get_height()), ','),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=22, xytext=(0, 9),
                   textcoords='offset points')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Medals_won_df.reset_index(inplace=True)
Medals_won_df=Medals_won_df.set_index('Sport')
hockey_df=Medals_won_df.loc['Hockey']
hockey_gold_ind=hockey_df.groupby(['NOC'])['Gold'].count().sort_values(ascending=False)
most_medals_won_in_hockey=hockey_gold_ind.head(1)
most_medals_won_in_hockey
# Out:
# NOC
# IND    27
# Name: Gold, dtype: int64

# %%
hockey_gold_ind_by_year=hockey_df.groupby(['NOC','Year'])['Gold'].count()['IND']
hockey_gold_ind_by_year
# Out:
# Year
# 1928    3
# 1932    6
# 1936    5
# 1948    4
# 1952    4
# 1956    1
# 1960    0
# 1964    1
# 1968    0
# 1972    0
# 1980    3
# Name: Gold, dtype: int64

# %%
# Single line chart
import matplotlib.pyplot as plt
from matplotlib import style
# setting style for graphs
style.use('Solarize_Light2')
plt.rcParams['figure.figsize'] = (20,10)

hockey_gold_ind_by_year.plot(kind = 'line', color = 'r')
plt.title('Gold medals won in Hockey by India from 1928-1980',color = 'black',size=30)
plt.xlabel('Year',size=30,color = 'black')
plt.ylabel('Number of medals',size=30,color = 'black')
plt.xticks(color = 'black',size=22)
plt.yticks(color = 'black',size=22)
plt.savefig('Line_Chart.png')

plt.show()

# %%
Total_sports_played_in_olympics=df['Sport'].nunique()
Total_sports_played_in_olympics
# Out:
# 65

# %%
#Medals won by each sport in olympics
Medals_won_by_sport=Medals_won_df.groupby(['Sport'])['Medal'].count().sort_values(ascending=False)
sports_won_most_medals=Medals_won_by_sport
sports_won_most_medals
# Out:
# Sport
# Athletics              1056
# Rowing                  781
# Swimming                681
# Gymnastics              466
# Fencing                 461
#                        ...
# Military Ski Patrol       4
# Motorboating              2
# Croquet                   2
# Roque                     1
# Basque Pelota             1
# Name: Medal, Length: 64, dtype: int64

# %%
#Medals won by each sport in olympics
# bar chart
# Do not change the style back to ggplot 
# delete the style.use('ggplot') line of code
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
import seaborn as sns

sports_won_most_medals.plot(kind = 'bar',figsize=(63,24))
plt.title('\n Medals won by each sport in olympics \n',size=63)
plt.ylabel('\n Medals won \n',size=22)
plt.xlabel('\n Sport\n',size=63)
plt.xticks(color='white',size=42)
plt.yticks(color='white',size=42)
plt.legend(loc='upper right', title='The Legend',prop={'size': 42})

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Number of gold, silver, bronze medals in top15 most Medals won sports
Medals_won_df.reset_index(inplace=True)
Medals_won_df=Medals_won_df.set_index('Sport')
Medal_counts_won_by_each_sport=Medals_won_df.groupby(['Sport'])['Gold','Silver','Bronze'].count()
Medal_counts_won_by_each_sport['total']=Medal_counts_won_by_each_sport.sum(axis = 1)
medals_Sport=Medal_counts_won_by_each_sport.sort_values(by=['total'],ascending=False)
Medals_won_by_each_sport=medals_Sport[['Gold','Silver','Bronze']]
Medals_won_by_each_sport
Top15_sports_won_most_Medals=Medals_won_by_each_sport.head(15)
Top15_sports_won_most_Medals
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\2738927424.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Medal_counts_won_by_each_sport=Medals_won_df.groupby(['Sport'])['Gold','Silver','Bronze'].count()
#             Gold  Silver  Bronze
# Sport
# Athletics    365     350     341
# Rowing       263     271     247
# Swimming     250     201     230
# Gymnastics   182     139     145
# Fencing      161     160     140
# Hockey       138     156     153
# Football     132     151     133
# Sailing      136     116     108
# Ice Hockey   115     120     104
# Basketball   107      92     106
# Canoeing     105      87     108
# Cycling      112      97      89
# Shooting      98      88     108
# Water Polo    99      98      91
# Wrestling     82      98      93

# %%
#top15 most Medals won sports
# bar chart
# Do not change the style back to ggplot 
# delete the style.use('ggplot') line of code
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
import seaborn as sns

plots=Top15_sports_won_most_Medals.plot(kind = 'bar',figsize=(30,16),colormap='Paired')
plt.title('\n  top15 most Medals won  \n',size=63)
plt.ylabel('\n Medals won \n',size=22)
plt.xlabel('\n Sport\n',size=63)
plt.xticks(color='white',size=42)
plt.yticks(color='white',size=42)
plt.legend(loc='upper right', title='The Legend',prop={'size': 42})
for bar in plots.patches:
    plots.annotate(format(int(bar.get_height()), ','),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=22, xytext=(0, 9),
                   textcoords='offset points')


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Athletics_medals_per_year
Athletics_medals=Medals_won_df.loc['Athletics']
Athletics_medals_per_year=Athletics_medals.groupby(['Year'])['Gold','Silver','Bronze'].count()
Athletics_medals_per_year
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\738981778.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Athletics_medals_per_year=Athletics_medals.groupby(['Year'])['Gold','Silver','Bronze'].count()
#       Gold  Silver  Bronze
# Year
# 1896     6       3       2
# 1900     8      13       4
# 1904     5       9       4
# 1906     3       2       7
# 1908     8      10      10
# 1912    12      11      11
# 1920     5      10      19
# 1924     5      11      13
# 1928    12      12      10
# 1932    11      10      10
# 1936     5      14       8
# 1948    16       9       6
# 1952    11      10      14
# 1956    18       8       5
# 1960    13       7       4
# 1964    13      16      15
# 1968    10      10      11
# 1972    12      12      12
# 1976    10       8      16
# 1980    13      13       9
# 1984    26      18      14
# 1988    16      21      17
# 1992    15      17      15
# ...

# %%
# Cyberpunk Multiple Line Chart
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
plt.figure(figsize = (20,7))
Athletics_medals_per_year.plot(kind = 'line')
plt.title('\n medals in Athletics from 1896-2016\n',size=22,color = 'white')
plt.ylabel('\n Number of medals \n',size=22,color = 'white')
plt.xlabel('\n Year \n',size=22,color = 'white')
plt.legend(loc='upper left', title='The Legend',prop={'size': 13})
plt.xticks(color = 'white',size=22)
plt.yticks(color = 'white',size=22)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#No of medals by each game
#Medals_won_df.reset_index(inplace=True)
medal_groupby_Game=Medals_won_df.groupby(['Year'])['Gold','Silver','Bronze'].count()
medal_groupby_Game
medal_groupby_Game['total']=medal_groupby_Game.sum(axis = 1)
medal_groupby_Game
medal_groupby_Game_sort=medal_groupby_Game.sort_values('Year',ascending=True)
medal_groupby_Game_sort
medal_groupby_Game_counts=medal_groupby_Game_sort[['Gold','Silver','Bronze']]
medal_groupby_Game_counts
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\2495900547.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   medal_groupby_Game=Medals_won_df.groupby(['Year'])['Gold','Silver','Bronze'].count()
#       Gold  Silver  Bronze
# Year
# 1896    12       8       5
# 1900    69      64      51
# 1904    47      43      34
# 1906    38      41      33
# 1908    80      74      69
# 1912    84      73      82
# 1920   120     132     119
# 1924    82      94      90
# 1928    73      71      77
# 1932    69      70      60
# 1936    90      87      74
# 1948    98      83      95
# 1952    87      97      87
# 1956    97      78      78
# 1960    93      75      99
# 1964   109      86      88
# 1968    91      69      97
# 1972    96     103     113
# 1976   111     118     130
# 1980   120     129     132
# 1984   165     137     143
# 1988   141     147     132
# 1992   159     163     156
# ...

# %%
# Cyberpunk Multiple Line Chart
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
plt.figure(figsize = (20,7))
medal_groupby_Game_counts.plot(kind = 'line')
plt.title('\n No of medals won from 1896-2016\n',size=22,color = 'white')
plt.ylabel('\n Number of medals \n',size=22,color = 'white')
plt.xlabel('\n Year \n',size=22,color = 'white')
plt.legend(loc='upper left', title='The Legend',prop={'size': 13})
plt.xticks(color = 'white',size=22)
plt.yticks(color = 'white',size=22)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Medals_won_df.reset_index(inplace=True)
Medals_won_df=Medals_won_df.set_index('Season')
summer_df=Medals_won_df.loc['Summer']
summer_df
summer_df_season=summer_df.groupby(['Season','Sport'])['Gold','Silver','Bronze'].count()
summer_df_season.reset_index(inplace=True)
summer_df_season_counts=summer_df_season[['Sport','Gold','Silver','Bronze']].set_index('Sport')
summer_df_season_counts['total']=summer_df_season_counts.sum(axis = 1)
Top5_medal_count_in_summer_olympics=summer_df_season_counts.sort_values(by='total',ascending=False).head(5)
Top5_medal_count_in_summer_olympics
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\806958824.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   summer_df_season=summer_df.groupby(['Season','Sport'])['Gold','Silver','Bronze'].count()
#             Gold  Silver  Bronze  total
# Sport
# Athletics    365     350     341   1056
# Rowing       263     271     247    781
# Swimming     250     201     230    681
# Gymnastics   182     139     145    466
# Fencing      161     160     140    461

# %%
Top5_medal_count_in_summer_olympics.reset_index(inplace=True)
summer_medals=Top5_medal_count_in_summer_olympics[['Sport','total']]
summer_medals
# Out:
#         Sport  total
# 0   Athletics   1056
# 1      Rowing    781
# 2    Swimming    681
# 3  Gymnastics    466
# 4     Fencing    461

# %%
#Lollipop chart
import matplotlib.pyplot as plt
  
# reading CSV file
d = summer_medals
# creating an empty chart
fig, axes = plt.subplots()
  
# plotting using plt.stem
axes.stem(summer_medals['Sport'], summer_medals['total'],
          use_line_collection=True, basefmt=' ')
  
# starting value of y-axis
axes.set_ylim(0)
  
# details and formatting of chart
plt.title('Top 5 most medals won in summer season',size=42)
plt.xlabel('Sport',size=22)
plt.ylabel('Profit')
plt.xticks(summer_medals['Sport'],size=22)
plt.yticks(summer_medals['total'],size=22)
plt.show
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\1392671856.py:10: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   axes.stem(summer_medals['Sport'], summer_medals['total'],
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Medals_won_df.reset_index(inplace=True)
medals_by_season=Medals_won_df.groupby(['Season'])['Gold','Silver','Bronze'].count()
medals_by_season
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\3233971802.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   medals_by_season=Medals_won_df.groupby(['Season'])['Gold','Silver','Bronze'].count()
#         Gold  Silver  Bronze
# Season
# Summer  2856    2747    2797
# Winter   434     441     411

# %%
#No of Gold, Silver and Bronze medals won by top 5 most successfull countries
# bar chart
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
# setting style for graphs
#style.use('Solarize_Light2')
plt.rcParams['figure.figsize'] = (30,16)

plots=medals_by_season.plot(kind = 'bar')
plt.title('No of Gold, Silver and Bronze medals won in each season',color = 'white',size=30)
plt.xlabel('season',size=30,color = 'white')
plt.ylabel('No of medals',size=30,color = 'white')
plt.xticks(color = 'white',size=22)
plt.yticks(color = 'white',size=22)
plt.legend(loc='upper right', title='The Legend',prop={'size': 22})
plt.savefig('Line_Chart.png')
for bar in plots.patches:
    plots.annotate(format(int(bar.get_height()), ','),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=22, xytext=(0, 9),
                   textcoords='offset points')
    

plt.show()

# %%
#How many tug of war medals USA won
#Medals_won_df.reset_index(inplace=True)
Medals_won=Medals_won_df.groupby(['Sport','NOC'])['Gold','Silver','Bronze'].count()
Medals_won.reset_index(inplace=True)
Medals_won=Medals_won.set_index('Sport')
tug_of_war_medals=Medals_won.loc['Tug-Of-War']
tug_of_war_medals.reset_index(inplace=True)
tug_of_war_medals_by_USA=tug_of_war_medals[['NOC','Gold','Silver','Bronze']].set_index('NOC').loc['USA']
tug_of_war_medals_by_USA
# Out:
# C:\Users\Prasad\AppData\Local\Temp\ipykernel_14256\4223403235.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Medals_won=Medals_won_df.groupby(['Sport','NOC'])['Gold','Silver','Bronze'].count()
# Gold      0
# Silver    1
# Bronze    0
# Name: USA, dtype: int64

# %%
#Top 5 athletes who have won the most medals (gold/silver/bronze). Order the results by medals in descending.
groupby_name=Medals_won_df.groupby(['Name'])['Medal'].count()
groupby_name_desc=groupby_name.sort_values(ascending=False)
Top_5_athletes_who_have_won_the_most_medals=groupby_name_desc.head(5)
Top_5_athletes_who_have_won_the_most_medals
# Out:
# Name
# Nikolay Yefimovich Andrianov     15
# Ole Einar Bjrndalen              13
# Birgit Fischer-Schmidt           12
# Natalie Anne Coughlin (-Hall)    12
# Viktor Ivanovych Chukarin        11
# Name: Medal, dtype: int64

# %%
# Here I want to query using SQL in Jupiter notebook quickly.

# Here I am creating Olympic database.
import sqlite3 as sl
conn = sl.connect('Olympic.db')

print ("Opened database successfully")
# Out:
# Opened database successfully

# %%
#Add a new table to your database called OlympicData using the data in the dataframe.
OlympicData = df.to_sql('OlympicData',conn, if_exists = 'replace')

# %%
# Here I am checking the OlympicData created or not by displaying data.
pd.read_sql('select * from OlympicData limit 4', conn)
# Out:
#    index  ID                  Name Sex   Age            Team  NOC  \
# 0      0   1             A Dijiang   M  24.0           China  CHN
# 1      1   2              A Lamusi   M  23.0           China  CHN
# 2      2   3   Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3      3   4  Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
# 3  1900 Summer  1900  Summer      Paris  Tug-Of-War
#
#                           Event       Medal
# 0   Basketball Men's Basketball  Medal-less
# 1  Judo Men's Extra-Lightweight  Medal-less
# 2       Football Men's Football  Medal-less
# 3   Tug-Of-War Men's Tug-Of-War        Gold

# %%
#How many olympics games have been held?
Total_olympics_games_held=pd.read_sql('''select count(distinct Games) as Total_olympics_games_held 
                                               from OlympicData ''', conn)
Total_olympics_games_held
# Out:
#    Total_olympics_games_held
# 0                         51

# %%
#List down all Olympics games held so far. Order the result by year.
pd.read_sql('select distinct Games from OlympicData order by Year  ', conn)
# Out:
#           Games
# 0   1896 Summer
# 1   1900 Summer
# 2   1904 Summer
# 3   1906 Summer
# 4   1908 Summer
# 5   1912 Summer
# 6   1920 Summer
# 7   1924 Summer
# 8   1924 Winter
# 9   1928 Summer
# 10  1928 Winter
# 11  1932 Summer
# 12  1932 Winter
# 13  1936 Summer
# 14  1936 Winter
# 15  1948 Summer
# 16  1948 Winter
# 17  1952 Summer
# 18  1952 Winter
# 19  1956 Winter
# 20  1956 Summer
# 21  1960 Winter
# 22  1960 Summer
# 23  1964 Winter
# 24  1964 Summer
# 25  1968 Summer
# 26  1968 Winter
# 27  1972 Summer
# 28  1972 Winter
# 29  1976 Summer
# 30  1976 Winter
# 31  1980 Winter
# 32  1980 Summer
# 33  1984 Winter
# 34  1984 Summer
# 35  1988 Winter
# 36  1988 Summer
# 37  1992 Summer
# 38  1992 Winter
# 39  1994 Winter
# 40  1996 Summer
# 41  1998 Winter
# 42  2000 Summer
# 43  2002 Winter
# 44  2004 Summer
# 45  2006 Winter
# 46  2008 Summer
# 47  2010 Winter
# 48  2012 Summer
# 49  2014 Winter
# 50  2016 Summer

# %%
#Mention the total no of nations who participated in each olympics game?. Order the results by games
pd.read_sql('''select Games,count(distinct NOC) as nations_participated  
               from OlympicData 
               group by Games 
               order by Games''',conn)
# Out:
#           Games  nations_participated
# 0   1896 Summer                     7
# 1   1900 Summer                    20
# 2   1904 Summer                    10
# 3   1906 Summer                    19
# 4   1908 Summer                    18
# 5   1912 Summer                    24
# 6   1920 Summer                    26
# 7   1924 Summer                    39
# 8   1924 Winter                    16
# 9   1928 Summer                    43
# 10  1928 Winter                    23
# 11  1932 Summer                    39
# 12  1932 Winter                    15
# 13  1936 Summer                    47
# 14  1936 Winter                    24
# 15  1948 Summer                    52
# 16  1948 Winter                    26
# 17  1952 Summer                    62
# 18  1952 Winter                    27
# 19  1956 Summer                    66
# 20  1956 Winter                    26
# 21  1960 Summer                    80
# 22  1960 Winter                    28
# 23  1964 Summer                    83
# ...

# %%
#Which nation has participated in all of the olympic games? and order the output by first column which is fetched
Nations=pd.read_sql('''select NOC,count(distinct Games) as no_of_olympic_games_participated 
                    from OlympicData 
                    group by NOC 
                    having count(distinct Games)=51 order by NOC''', conn)
Nations
# Out:
#    NOC  no_of_olympic_games_participated
# 0  FRA                                51
# 1  GBR                                51

# %%
#How many unique athletes have won a gold medal in the Olympics?
no_of_athletes_won_gold_medal=pd.read_sql('''select count(distinct Name) as Athletes,Medal 
                                       from OlympicData 
                                       where Medal like "%Gold%" ''',conn)
no_of_athletes_won_gold_medal
# Out:
#    Athletes Medal
# 0      2568  Gold

# %%
#Which Sports were just played only once in the olympics? 
Sports_played_once=pd.read_sql('''select Sport,Games ,count(distinct Games) as no_of_games
                                  from OlympicData 
                                  group by sport
                                  having count(distinct Games)=1
                                  order by Sport''', conn)
Sports_played_once
# Out:
#                  Sport        Games  no_of_games
# 0        Basque Pelota  1900 Summer            1
# 1              Cricket  1900 Summer            1
# 2              Croquet  1900 Summer            1
# 3         Jeu De Paume  1908 Summer            1
# 4  Military Ski Patrol  1924 Winter            1
# 5         Motorboating  1908 Summer            1
# 6             Racquets  1908 Summer            1
# 7                Roque  1904 Summer            1
# 8         Rugby Sevens  2016 Summer            1

# %%
#Fetch the total no of sports played in each olympic games. Order by no of sports by descending.

Sports=pd.read_sql('''select Games ,count(distinct Sport) as no_of_sports
                       from OlympicData 
                       group by Games
                       order by no_of_sports desc''', conn)
Sports
# Out:
#           Games  no_of_sports
# 0   2016 Summer            34
# 1   2008 Summer            34
# 2   2004 Summer            34
# 3   2000 Summer            34
# 4   2012 Summer            32
# 5   1996 Summer            31
# 6   1992 Summer            29
# 7   1988 Summer            27
# 8   1984 Summer            25
# 9   1920 Summer            25
# 10  1908 Summer            24
# 11  1980 Summer            23
# 12  1976 Summer            23
# 13  1972 Summer            23
# 14  1936 Summer            23
# 15  1964 Summer            21
# 16  1968 Summer            20
# 17  1948 Summer            20
# 18  1924 Summer            20
# 19  1900 Summer            20
# 20  1960 Summer            19
# 21  1956 Summer            19
# 22  1952 Summer            19
# 23  1932 Summer            17
# 24  1928 Summer            17
# 25  1912 Summer            17
# 26  1904 Summer            17
# 27  2014 Winter            15
# 28  2010 Winter            15
# 29  2006 Winter            15
# ...

# %%
#Fetch oldest athletes to win a gold medal
oldest_athletes=pd.read_sql('''select max(Age) as Age , 
                               Name ,Medal from OlympicData 
                               where Medal like '%Gold%' ''',conn)
oldest_athletes
# Out:
#     Age                   Name Medal
# 0  59.0  Everard Coenraad Endt  Gold

# %%
#Top 5 athletes who have won the most gold medals. Order the results by gold medals in descending.
Top_5_athletes_who_have_won_the_most_gold_medals=pd.read_sql('''select Name,count(Medal) as Gold_Medals_Won,Medal 
                                                                from OlympicData 
                                                                group by Name,Medal
                                                                having Medal like '%Gold%' 
                                                                order by Gold_Medals_Won desc limit 5
                                                                ''',conn)
Top_5_athletes_who_have_won_the_most_gold_medals
# Out:
#                              Name  Gold_Medals_Won Medal
# 0     Raymond Clarence "Ray" Ewry               10  Gold
# 1          Birgit Fischer-Schmidt                8  Gold
# 2  Matthew Nicholas "Matt" Biondi                8  Gold
# 3             Ole Einar Bjrndalen                8  Gold
# 4              Usain St. Leo Bolt                8  Gold

# %%
#Top 5 athletes who have won the most medals (gold/silver/bronze). Order the results by medals in descending.
pd.read_sql('''select Name,sum(Medals_Won) as No_Medals_won from(select Name,count(Medal) as Medals_Won,Medal 
               from OlympicData 
               group by Name,Medal
               having Medal like '%Gold%' or Medal like '%silver%' or Medal like '%bronze%'
               ) as Medals_count_by_Medal group by Name order by No_Medals_won desc limit 5
               
               ''',conn)
# Out:
#                             Name  No_Medals_won
# 0   Nikolay Yefimovich Andrianov             15
# 1            Ole Einar Bjrndalen             13
# 2  Natalie Anne Coughlin (-Hall)             12
# 3         Birgit Fischer-Schmidt             12
# 4         Vra slavsk (-Odloilov)             11

# %%
#Top 5 most successful countries in olympics. Success is defined by no of medals won.
pd.read_sql('''select NOC,sum(Medals_won) as No_of_Medals_won from (select NOC,count(Medal) as Medals_won,Medal 
               from OlympicData 
               group by NOC,Medal
               having Medal like '%Gold%' or Medal like '%Silver%' or Medal like '%Bronze%'
               ) as medals_count group by NOC order by sum(Medals_won) desc limit 5
             ''',conn)
# Out:
#    NOC  No_of_Medals_won
# 0  USA              1561
# 1  FRA               657
# 2  ITA               604
# 3  GBR               603
# 4  URS               515

# %%
Top_5_most_successful_countries=pd.read_sql('''select NOC from 
                                              (select NOC,count(Medal) as Medals_won,Medal 
                                               from OlympicData 
                                               group by NOC,Medal
                                               having Medal like '%Gold%' or Medal like '%Silver%' or Medal like '%Bronze%'
                                             ) as medals_count group by NOC order by sum(Medals_won) desc limit 5
                                             ''',conn)
Top_5_most_successful_countries
# Out:
#    NOC
# 0  USA
# 1  FRA
# 2  ITA
# 3  GBR
# 4  URS

# %%
#In which Sport/event, India has won highest medals.
pd.read_sql('''select NOC,count(Medal) as Medals_won,Medal,Sport,Event 
               from OlympicData 
               group by NOC,Medal,Event
               having (Medal like '%Gold%' or Medal like '%Silver%' or Medal like '%Bronze%') and NOC='IND'
               order by count(Medal) desc limit 5
             ''',conn)
# Out:
#    NOC  Medals_won   Medal      Sport                                   Event
# 0  IND          27    Gold     Hockey                     Hockey Men's Hockey
# 1  IND           3  Bronze     Hockey                     Hockey Men's Hockey
# 2  IND           2  Silver     Hockey                     Hockey Men's Hockey
# 3  IND           1  Bronze  Wrestling  Wrestling Men's Lightweight, Freestyle
# 4  IND           1    Gold   Shooting     Shooting Men's Air Rifle, 10 metres

# %%
pd.read_sql('''select NOC,count(Medal) as Medals_won,Medal,Sport,Event 
               from OlympicData 
               group by NOC,Medal,Event
               having (Medal like '%Gold%' or Medal like '%Silver%' or Medal like '%Bronze%') and NOC='IND'
               order by count(Medal) desc limit 1
             ''',conn)
# Out:
#    NOC  Medals_won Medal   Sport                Event
# 0  IND          27  Gold  Hockey  Hockey Men's Hockey

# %%
#Break down all olympic games where india won medal for Hockey and how many medals in each olympic games and 
#order the result by no of medals in descending.

pd.read_sql('''select NOC,count(Medal) as Medals_won,Medal,Sport,Event,Games 
               from OlympicData 
               group by NOC,Medal,Event
               having (Medal like '%Gold%' or Medal like '%Silver%' or Medal like '%Bronze%') and NOC='IND' and Sport='Hockey'
               order by count(Medal) desc limit 5
             ''',conn)
# Out:
#    NOC  Medals_won   Medal   Sport                Event        Games
# 0  IND          27    Gold  Hockey  Hockey Men's Hockey  1928 Summer
# 1  IND           3  Bronze  Hockey  Hockey Men's Hockey  1972 Summer
# 2  IND           2  Silver  Hockey  Hockey Men's Hockey  1960 Summer
